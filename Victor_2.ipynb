# %%
# Declaration of variables

# %%
name = ('Victor Gideon')

# %%
age = (20)

# %%
school = ('CoLab Innovation Institute')

# %%
favorite_subject = ('Data Science')

# %%
# Printing a statement introducing myself using the above variables

# %%
print(f"My name is", (name),", I am", (age),"years old. I school in", (school), "and my favorite subject is", (favorite_subject),'.')
# Out:
# My name is Victor Gideon , I am 20 years old. I school in CoLab Innovation Institute and my favorite subject is Data Science .

# %%
# a short motivational quote

# %%
quote = ("Every new day is a new opportunity to make it right")

# %%
# Manipulating quote using string methods

# %%
quote.replace('is', '')
# Out:
# 'Every new day  a new opportunity to make it right'

# %%
best_friend_name = input("input the name of your best friend: ")
# Out:
# input the name of your best friend:  h

# %%
print('I wish you and', (best_friend_name), 'a happy and lasting friendship.')
# Out:
# I wish you and Dami a happy and lasting friendship.

# %%
print((name),'and',(best_friend_name),'were born in the early 2000. Although, both born in same month, they share different dates...')
# Out:
# Victor Gideon and Dami were born in the early 2000. Although, both born in same month, they share different dates...
